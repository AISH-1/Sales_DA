# %% [markdown]
# # 🏬 Store Item Demand Forecasting Challenge
#
# **Competition Link**: [Kaggle - Demand Forecasting Kernels Only](https://www.kaggle.com/competitions/demand-forecasting-kernels-only/overview)
#
# ## 📝 Objective
#
# The goal of this competition is to **predict daily item sales** for the next **3 months** across multiple **stores**. The dataset is relatively simple and ideal for practicing **time series forecasting techniques**.
#
# ---
#
# ## 📊 Dataset Description
#
# The dataset consists of **historical daily sales data** for 50 different items sold across 10 different stores.
#
# There are **3 files** provided:
#
# ### 1. `train.csv`
# - Contains the historical sales data used for training.
# - Columns:
#   - `date` - Date of the sales record (`YYYY-MM-DD`)
#   - `store` - Store ID (from 1 to 10)
#   - `item` - Item ID (from 1 to 50)
#   - `sales` - Number of units sold
#
# ### 2. `test.csv`
# - Contains the dates and corresponding store-item pairs for which predictions are required.
# - Columns:
#   - `id` - Unique row ID
#   - `date` - Forecast date
#   - `store` - Store ID
#   - `item` - Item ID
#
# ### 3. `sample_submission.csv`
# - Sample format of the required submission file.
# - Columns:
#   - `id` - Must match the test file
#   - `sales` - Predicted number of sales (to be filled)
#
# ---
#
# ## 📅 Date Range
#
# - **Training Data**: Starts from **2013-01-01** to **2017-12-31**
# - **Forecasting Period**: **2018-01-01 to 2018-03-31** (91 days)

# %%
pip install pandas numpy matplotlib seaborn scikit-learn xgboost lightgbm catboost jupyter
# Out:
# Requirement already satisfied: pandas in d:\python_workspace\sales_da\.venv\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in d:\python_workspace\sales_da\.venv\lib\site-packages (2.1.3)
# Requirement already satisfied: matplotlib in d:\python_workspace\sales_da\.venv\lib\site-packages (3.10.3)
# Requirement already satisfied: seaborn in d:\python_workspace\sales_da\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in d:\python_workspace\sales_da\.venv\lib\site-packages (1.7.0)
# Requirement already satisfied: xgboost in d:\python_workspace\sales_da\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: lightgbm in d:\python_workspace\sales_da\.venv\lib\site-packages (4.6.0)
# Requirement already satisfied: catboost in d:\python_workspace\sales_da\.venv\lib\site-packages (1.2.8)
# Requirement already satisfied: jupyter in d:\python_workspace\sales_da\.venv\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: graphviz in d:\python_workspace\sales_da\.venv\lib\site-packages (from catboost) (0.20.3)
# Requirement already satisfied: plotly in d:\python_workspace\sales_da\.venv\lib\site-packages (from catboost) (6.1.2)
# Requirement already satisfied: six in d:\python_workspace\sales_da\.venv\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: notebook in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (7.4.3)
# Requirement already satisfied: jupyter-console in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter) (4.4.3)
# Requirement already satisfied: comm>=0.1.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (26.4.0)
# Requirement already satisfied: tornado>=6.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: colorama in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.1)
# Requirement already satisfied: stack_data in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.14.0)
# Requirement already satisfied: wcwidth in d:\python_workspace\sales_da\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.8)
# Requirement already satisfied: pywin32>=300 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (310)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\python_workspace\sales_da\.venv\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab->jupyter) (65.5.0)
# Requirement already satisfied: anyio>=3.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.9.0)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.24.0)
# Requirement already satisfied: requests>=2.31 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: idna>=2.8 in d:\python_workspace\sales_da\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: sniffio>=1.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\python_workspace\sales_da\.venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: certifi in d:\python_workspace\sales_da\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in d:\python_workspace\sales_da\.venv\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\python_workspace\sales_da\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.25.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in d:\python_workspace\sales_da\.venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\python_workspace\sales_da\.venv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.4.0)
# Requirement already satisfied: cffi>=1.0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in d:\python_workspace\sales_da\.venv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: soupsieve>1.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\python_workspace\sales_da\.venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250516)
# Requirement already satisfied: narwhals>=1.15.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from plotly->catboost) (1.41.1)
# Requirement already satisfied: executing>=1.2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in d:\python_workspace\sales_da\.venv\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install tensorflow
# %pip install keras
# Out:
# Requirement already satisfied: tensorflow in d:\python_workspace\sales_da\.venv\lib\site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (1.72.1)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python_workspace\sales_da\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras in d:\python_workspace\sales_da\.venv\lib\site-packages (3.10.0)
# Requirement already satisfied: absl-py in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (2.3.0)
# Requirement already satisfied: numpy in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (2.1.3)
# Requirement already satisfied: rich in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (0.16.0)
# Requirement already satisfied: ml-dtypes in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (0.5.1)
# Requirement already satisfied: packaging in d:\python_workspace\sales_da\.venv\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from optree->keras) (4.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\python_workspace\sales_da\.venv\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in d:\python_workspace\sales_da\.venv\lib\site-packages (0.14.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from statsmodels) (2.1.3)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in d:\python_workspace\sales_da\.venv\lib\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in d:\python_workspace\sales_da\.venv\lib\site-packages (from statsmodels) (2.3.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\python_workspace\sales_da\.venv\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in d:\python_workspace\sales_da\.venv\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\python_workspace\sales_da\.venv\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\python_workspace\sales_da\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

import matplotlib.colors as col
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import datetime
from pathlib import Path  
import random

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import KFold, cross_val_score, train_test_split


import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.callbacks import EarlyStopping
# from keras.utils import np_utils  # Deprecated, use keras.utils.to_categorical directly if needed
from keras.layers import LSTM

import lightgbm as lgb
import catboost as cb
import statsmodels.tsa.api as smt
import statsmodels.api as sm
from statsmodels.tools.eval_measures import rmse


import pickle
import warnings

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
dataset = pd.read_csv('sample_submission.csv')
df = dataset.copy()
df.head()
# Out:
#    id  sales
# 0   0     52
# 1   1     52
# 2   2     52
# 3   3     52
# 4   4     52

# %%
def load_data(file_name):
    return pd.read_csv(file_name)

# %%
sales_data = load_data('train.csv')
df_s = sales_data.copy()
df_s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  object
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 27.9+ MB

# %%
df_s.tail()
# Out:
#               date  store  item  sales
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82

# %%
df_s['sales'].describe()
# Out:
# count    913000.000000
# mean         52.250287
# std          28.801144
# min           0.000000
# 25%          30.000000
# 50%          47.000000
# 75%          70.000000
# max         231.000000
# Name: sales, dtype: float64

# %%
df_s['sales'].plot()
# Out:
# <Axes: >

# %% [markdown]
# Returns a dataframe row represents total sales for a given month. Columns include 'date' by month and 'sales'.

# %%
def monthlyORyears_sales(data,time=['monthly','years']):
    data = data.copy()
    if time == "monthly":
        # Drop the day indicator from the date column:
        data.date = data.date.apply(lambda x: str(x)[:-3])
    else:
        data.date = data.date.apply(lambda x: str(x)[:4])
        
   # Sum sales per month: 
    data = data.groupby('date')['sales'].sum().reset_index()
    data.date = pd.to_datetime(data.date)
        
    return data

# %%
m_df = monthlyORyears_sales(df_s,"monthly")

m_df.to_csv('./monthly_data.csv')

# %%
m_df.head(10)
# Out:
#         date   sales
# 0 2013-01-01  454904
# 1 2013-02-01  459417
# 2 2013-03-01  617382
# 3 2013-04-01  682274
# 4 2013-05-01  763242
# 5 2013-06-01  795597
# 6 2013-07-01  855922
# 7 2013-08-01  766761
# 8 2013-09-01  689907
# 9 2013-10-01  656587

# %% [markdown]
# > In our new data frame, each row now represents the total sales for a given month across stores.

# %%
y_df = monthlyORyears_sales(df_s,"years")
y_df
# Out:
#         date     sales
# 0 2013-01-01   7941243
# 1 2014-01-01   9135482
# 2 2015-01-01   9536887
# 3 2016-01-01  10357160
# 4 2017-01-01  10733740

# %%
layout = (1, 2)

raw = plt.subplot2grid(layout, (0 ,0))
law = plt.subplot2grid(layout, (0 ,1))

years = y_df['sales'].plot(kind = "bar",color = 'mediumblue', label="Sales",ax=raw, figsize=(12,5))
months = m_df['sales'].plot(marker = 'o',color = 'darkorange', label="Sales", ax=law)

years.set(xlabel = "Years",title = "Distribution of Sales Per Year")
months.set(xlabel = "Months", title = "Distribution of Sales Per Mounth")

sns.despine()
plt.tight_layout()

years.legend()
months.legend()

# %% [markdown]
# There are many other models to forecast time series, such as weighted
# moving average models or autoregressive integrated moving average
# (ARIMA) models. Some of them require you to first remove the trend
# and seasonality. For example, if you are studying the number of active
# users on your website, and it is growing by 10% every month, you
# would have to remove this trend from the time series. Once the model
# is trained and starts making predictions, you would have to add the
# trend back to get the final predictions. Similarly, if you are trying to
# predict the amount of sunscreen lotion sold every month, you will
# probably observe strong seasonality: since it sells well every summer,
# a similar pattern will be repeated every year. You would have to
# remove this seasonality from the time series, for example by
# computing the difference between the value at each time step and the
# value one year earlier (this technique is called differencing). Again,
# after the model is trained and makes predictions, you would have to
# add the seasonal pattern back to get the final predictions.

# %% [markdown]
#  To make it stationary, we will calculate the difference between the sales of each month and add it to our data frame as a new column.

# %%
def sales_time(data):
    """Time interval of dataset:"""

    data.date = pd.to_datetime(data.date)
    n_of_days = data.date.max() - data.date.min()
    n_of_years = int(n_of_days.days / 365)
    
    print(f"Days: {n_of_days.days}\nYears: {n_of_years}\nMonth: {12 * n_of_years}")

# %%
sales_time(df_s)
# Out:
# Days: 1825
# Years: 5
# Month: 60

# %% [markdown]
# **Sales Data Per Store**

# %%
def sales_per_store(data):
    sales_by_store = data.groupby('store')['sales'].sum().reset_index()
    
    fig, ax = plt.subplots(figsize=(8,6))
    sns.barplot(x='store', y='sales', data=sales_by_store, color='darkred')
    
    ax.set(xlabel = "Store Id", ylabel = "Sum of Sales", title = "Total Sales Per Store")
    
    return sales_by_store

# %%
sales_per_store(df_s)
# Out:
#    store    sales
# 0      1  4315603
# 1      2  6120128
# 2      3  5435144
# 3      4  5012639
# 4      5  3631016
# 5      6  3627670
# 6      7  3320009
# 7      8  5856169
# 8      9  5025976
# 9     10  5360158

# %% [markdown]
# **Mean Monthly Sales**

# %%
# Overall for 5 years:

average_m_sales = m_df.sales.mean()
print(f"Overall Avarage Monthly Sales: ${average_m_sales}")

def avarage_12months():
# Last 1 years (this will be the forecasted sales):
    average_m_sales_1y = m_df.sales[-12:].mean()
    print(f"Last 12 months average monthly sales: ${average_m_sales_1y}")
avarage_12months()
# Out:
# Overall Avarage Monthly Sales: $795075.2
# Last 12 months average monthly sales: $894478.3333333334

# %% [markdown]
# The underlying principle is to model or estimate the trend and seasonality in the series and remove those from the series to get a stationary series. Then statistical forecasting techniques can be implemented in this series. The final step would be to convert the forecasted values into the original scale by applying trend and seasonality constraints back.

# %%
# def time_plot(data, x_col, y_col, title):
#     fig, ax = plt.subplots(figsize = (15,8))
#     sns.lineplot(x_col, y_col, Data = data, ax = ax, color = 'darkblue', label='Total Sales')
    
#     s_mean = data.groupby(data.date.dt.year)[y_col].mean().reset_index()
#     s_mean.date = pd.to_datetime(s_mean.date, format='%Y')
#     sns.lineplot((s_mean.date + datetime.timedelta(6*365/12)), y_col, data=s_mean, ax=ax, color='red', label='Mean Sales')   
    
#     ax.set(xlabel = "Years",
#            ylabel = "Sales",
#            title = title)

def time_plot(data, x_col, y_col, title):
    fig, ax = plt.subplots(figsize = (15,8))
    sns.lineplot(x=x_col, y=y_col, data=data, ax=ax, color='darkblue', label='Total Sales')
    
    s_mean = data.groupby(data[x_col].dt.year)[y_col].mean().reset_index()
    s_mean[x_col] = pd.to_datetime(s_mean[x_col], format='%Y')
    sns.lineplot(x=s_mean[x_col] + datetime.timedelta(days=int(6*365/12)), y=y_col, data=s_mean, ax=ax, color='red', label='Mean Sales')   
    
    ax.set(xlabel = "Years",
           ylabel = "Sales",
           title = title)

# %%
time_plot(m_df, x_col='date', y_col='sales', title='Monthly Sales Before Diff Transformation')

# %% [markdown]
# * **Differencing**
# In this method, we compute the difference of consecutive terms in the series. Differencing is typically performed to get rid of the varying mean.

# %%
def get_diff(data):
    """Calculate the difference in sales month over month:"""
    
    data['sales_diff'] = data.sales.diff()
    data = data.dropna()
    
    data.to_csv('./stationary_df.csv')
    
    return data

# %%
stationary_df = get_diff(m_df)
time_plot(stationary_df, 'date', 'sales_diff', 
          'Monthly Sales After Diff Transformation')

# %% [markdown]
# # **Preparing Dataset Modeling**

# %% [markdown]
# # ARIMA Modeling
#
# >  For our Arima model, we will need only a datetime index and the dependent variable (diff in sales) columns.

# %%
def build_arima_data(data):
    da_data = data.set_index('date').drop('sales', axis=1)
    da_data.dropna(axis=0)
    da_data.to_csv('arima_df.csv')
    return da_data

# %%
datatime_df = build_arima_data(stationary_df)
datatime_df # ARIMA Dataframe
# Out:
#             sales_diff
# date
# 2013-02-01      4513.0
# 2013-03-01    157965.0
# 2013-04-01     64892.0
# 2013-05-01     80968.0
# 2013-06-01     32355.0
# 2013-07-01     60325.0
# 2013-08-01    -89161.0
# 2013-09-01    -76854.0
# 2013-10-01    -33320.0
# 2013-11-01     36056.0
# 2013-12-01   -186036.0
# 2014-01-01     19380.0
# 2014-02-01      3130.0
# 2014-03-01    175184.0
# 2014-04-01     84613.0
# 2014-05-01     93963.0
# 2014-06-01     23965.0
# 2014-07-01     82168.0
# 2014-08-01   -103414.0
# 2014-09-01   -100472.0
# 2014-10-01    -26241.0
# 2014-11-01     41900.0
# 2014-12-01   -222735.0
# 2015-01-01    -25535.0
# 2015-02-01     -1196.0
# 2015-03-01    179634.0
# 2015-04-01     93516.0
# 2015-05-01    102435.0
# 2015-06-01     10282.0
# 2015-07-01    100166.0
# 2015-08-01   -116949.0
# 2015-09-01    -97069.0
# 2015-10-01    -26079.0
# 2015-11-01     30392.0
# 2015-12-01   -220073.0
# 2016-01-01     -5133.0
# 2016-02-01     12518.0
# 2016-03-01    175924.0
# 2016-04-01    111069.0
# 2016-05-01     86780.0
# 2016-06-01     33934.0
# 2016-07-01    116054.0
# 2016-08-01   -157224.0
# 2016-09-01    -84663.0
# 2016-10-01    -33194.0
# 2016-11-01     27811.0
# 2016-12-01   -228037.0
# 2017-01-01    -46105.0
# 2017-02-01      4063.0
# 2017-03-01    201298.0
# 2017-04-01    116195.0
# 2017-05-01     81824.0
# 2017-06-01     43938.0
# 2017-07-01    106769.0
# 2017-08-01   -144990.0
# 2017-09-01    -91140.0
# 2017-10-01    -44103.0
# 2017-11-01     37677.0
# 2017-12-01   -233667.0

# %% [markdown]
# * **Observing Lags**

# %% [markdown]
# For our other models, we will create a new data frame where each feature represents a previous month’s sales. To determine how many months to include in our feature set, we will observe the autocorrelation and partial autocorrelation plots and use the [rules for selecting lags in ARIMA modeling](https://people.duke.edu/~rnau/arimrule.htm). This way, we can keep consistent a look-back period for our ARIMA and regressive models.
#
# >  **[Statsmodels](https://www.statsmodels.org/dev/generated/statsmodels.graphics.tsaplots.plot_acf.html)**

# %%
def plots_lag(data, lags=None):
    """Convert dataframe to datetime index"""
    dt_data = data.set_index('date').drop('sales', axis=1)
    dt_data.dropna(axis=0)
    
    
    law  = plt.subplot(122)
    acf  = plt.subplot(221)
    pacf = plt.subplot(223)
    
    dt_data.plot(ax=law, figsize=(10, 5), color='orange')
    # Plot the autocorrelation function:
    smt.graphics.plot_acf(dt_data, lags=lags, ax=acf, color='mediumblue')
    smt.graphics.plot_pacf(dt_data, lags=lags, ax=pacf, color='mediumblue')
    plt.tight_layout()

plots_lag(stationary_df, lags=24);

# %% [markdown]
# > [🎦 Autocorrelation Function](https://www.youtube.com/watch?v=ZjaBn93YPWo&t=12s)
#
#
# >[ Time Series & Autocorrelation](https://online.stat.psu.edu/stat501/book/export/html/995 )

# %% [markdown]
# <div class="alert alert-block alert-danger" style ="background-color : #e6ebef;">
#     <p style="padding: 15px;
#               color:black;">📌 Based on the above, we will choose our look-back period to be 12 months. We will, therefore, generate a data frame that has 13 columns, 1 column for each of the 12 months and the column for our dependent variable, difference in sales.
#     </p>
# </div>

# %% [markdown]
# # Regressive Modeling
#
# > Let's create a CSV file where each row represents a month and the columns will have sales, dependent variables, and previous sales for each delay. The 12 delay properties are created according to the EDA. Data is used for regression modeling.

# %%
#Time series to supervised:
def built_supervised(data):
    supervised_df = data.copy()
    # Create column for each lag:
    for i in range(1, 13):
        col_name = 'lag_' + str(i)
        supervised_df[col_name] = supervised_df['sales_diff'].shift(i)

    # Drop null values:
    supervised_df = supervised_df.dropna().reset_index(drop=True)
    supervised_df.to_csv('./model_df.csv', index=False)
    return supervised_df

# %%
model_df = built_supervised(stationary_df)
model_df
# Out:
#          date    sales  sales_diff     lag_1     lag_2     lag_3     lag_4  \
# 0  2014-02-01   529117      3130.0   19380.0 -186036.0   36056.0  -33320.0
# 1  2014-03-01   704301    175184.0    3130.0   19380.0 -186036.0   36056.0
# 2  2014-04-01   788914     84613.0  175184.0    3130.0   19380.0 -186036.0
# 3  2014-05-01   882877     93963.0   84613.0  175184.0    3130.0   19380.0
# 4  2014-06-01   906842     23965.0   93963.0   84613.0  175184.0    3130.0
# 5  2014-07-01   989010     82168.0   23965.0   93963.0   84613.0  175184.0
# 6  2014-08-01   885596   -103414.0   82168.0   23965.0   93963.0   84613.0
# 7  2014-09-01   785124   -100472.0 -103414.0   82168.0   23965.0   93963.0
# 8  2014-10-01   758883    -26241.0 -100472.0 -103414.0   82168.0   23965.0
# 9  2014-11-01   800783     41900.0  -26241.0 -100472.0 -103414.0   82168.0
# 10 2014-12-01   578048   -222735.0   41900.0  -26241.0 -100472.0 -103414.0
# 11 2015-01-01   552513    -25535.0 -222735.0   41900.0  -26241.0 -100472.0
# 12 2015-02-01   551317     -1196.0  -25535.0 -222735.0   41900.0  -26241.0
# 13 2015-03-01   730951    179634.0   -1196.0  -25535.0 -222735.0   41900.0
# 14 2015-04-01   824467     93516.0  179634.0   -1196.0  -25535.0 -222735.0
# 15 2015-05-01   926902    102435.0   93516.0  179634.0   -1196.0  -25535.0
# 16 2015-06-01   937184     10282.0  102435.0   93516.0  179634.0   -1196.0
# 17 2015-07-01  1037350    100166.0   10282.0  102435.0   93516.0  179634.0
# 18 2015-08-01   920401   -116949.0  100166.0   10282.0  102435.0   93516.0
# 19 2015-09-01   823332    -97069.0 -116949.0  100166.0   10282.0  102435.0
# 20 2015-10-01   797253    -26079.0  -97069.0 -116949.0  100166.0   10282.0
# 21 2015-11-01   827645     30392.0  -26079.0  -97069.0 -116949.0  100166.0
# 22 2015-12-01   607572   -220073.0   30392.0  -26079.0  -97069.0 -116949.0
# 23 2016-01-01   602439     -5133.0 -220073.0   30392.0  -26079.0  -97069.0
# 24 2016-02-01   614957     12518.0   -5133.0 -220073.0   30392.0  -26079.0
# 25 2016-03-01   790881    175924.0   12518.0   -5133.0 -220073.0   30392.0
# 26 2016-04-01   901950    111069.0  175924.0   12518.0   -5133.0 -220073.0
# 27 2016-05-01   988730     86780.0  111069.0  175924.0   12518.0   -5133.0
# 28 2016-06-01  1022664     33934.0   86780.0  111069.0  175924.0   12518.0
# 29 2016-07-01  1138718    116054.0   33934.0   86780.0  111069.0  175924.0
# 30 2016-08-01   981494   -157224.0  116054.0   33934.0   86780.0  111069.0
# 31 2016-09-01   896831    -84663.0 -157224.0  116054.0   33934.0   86780.0
# 32 2016-10-01   863637    -33194.0  -84663.0 -157224.0  116054.0   33934.0
# 33 2016-11-01   891448     27811.0  -33194.0  -84663.0 -157224.0  116054.0
# 34 2016-12-01   663411   -228037.0   27811.0  -33194.0  -84663.0 -157224.0
# 35 2017-01-01   617306    -46105.0 -228037.0   27811.0  -33194.0  -84663.0
# 36 2017-02-01   621369      4063.0  -46105.0 -228037.0   27811.0  -33194.0
# 37 2017-03-01   822667    201298.0    4063.0  -46105.0 -228037.0   27811.0
# 38 2017-04-01   938862    116195.0  201298.0    4063.0  -46105.0 -228037.0
# 39 2017-05-01  1020686     81824.0  116195.0  201298.0    4063.0  -46105.0
# 40 2017-06-01  1064624     43938.0   81824.0  116195.0  201298.0    4063.0
# 41 2017-07-01  1171393    106769.0   43938.0   81824.0  116195.0  201298.0
# 42 2017-08-01  1026403   -144990.0  106769.0   43938.0   81824.0  116195.0
# 43 2017-09-01   935263    -91140.0 -144990.0  106769.0   43938.0   81824.0
# 44 2017-10-01   891160    -44103.0  -91140.0 -144990.0  106769.0   43938.0
# 45 2017-11-01   928837     37677.0  -44103.0  -91140.0 -144990.0  106769.0
# 46 2017-12-01   695170   -233667.0   37677.0  -44103.0  -91140.0 -144990.0
#
#        lag_5     lag_6     lag_7     lag_8     lag_9    lag_10    lag_11  \
# 0   -76854.0  -89161.0   60325.0   32355.0   80968.0   64892.0  157965.0
# 1   -33320.0  -76854.0  -89161.0   60325.0   32355.0   80968.0   64892.0
# 2    36056.0  -33320.0  -76854.0  -89161.0   60325.0   32355.0   80968.0
# 3  -186036.0   36056.0  -33320.0  -76854.0  -89161.0   60325.0   32355.0
# 4    19380.0 -186036.0   36056.0  -33320.0  -76854.0  -89161.0   60325.0
# 5     3130.0   19380.0 -186036.0   36056.0  -33320.0  -76854.0  -89161.0
# 6   175184.0    3130.0   19380.0 -186036.0   36056.0  -33320.0  -76854.0
# 7    84613.0  175184.0    3130.0   19380.0 -186036.0   36056.0  -33320.0
# 8    93963.0   84613.0  175184.0    3130.0   19380.0 -186036.0   36056.0
# 9    23965.0   93963.0   84613.0  175184.0    3130.0   19380.0 -186036.0
# 10   82168.0   23965.0   93963.0   84613.0  175184.0    3130.0   19380.0
# 11 -103414.0   82168.0   23965.0   93963.0   84613.0  175184.0    3130.0
# 12 -100472.0 -103414.0   82168.0   23965.0   93963.0   84613.0  175184.0
# 13  -26241.0 -100472.0 -103414.0   82168.0   23965.0   93963.0   84613.0
# 14   41900.0  -26241.0 -100472.0 -103414.0   82168.0   23965.0   93963.0
# 15 -222735.0   41900.0  -26241.0 -100472.0 -103414.0   82168.0   23965.0
# 16  -25535.0 -222735.0   41900.0  -26241.0 -100472.0 -103414.0   82168.0
# 17   -1196.0  -25535.0 -222735.0   41900.0  -26241.0 -100472.0 -103414.0
# 18  179634.0   -1196.0  -25535.0 -222735.0   41900.0  -26241.0 -100472.0
# 19   93516.0  179634.0   -1196.0  -25535.0 -222735.0   41900.0  -26241.0
# 20  102435.0   93516.0  179634.0   -1196.0  -25535.0 -222735.0   41900.0
# 21   10282.0  102435.0   93516.0  179634.0   -1196.0  -25535.0 -222735.0
# 22  100166.0   10282.0  102435.0   93516.0  179634.0   -1196.0  -25535.0
# 23 -116949.0  100166.0   10282.0  102435.0   93516.0  179634.0   -1196.0
# 24  -97069.0 -116949.0  100166.0   10282.0  102435.0   93516.0  179634.0
# 25  -26079.0  -97069.0 -116949.0  100166.0   10282.0  102435.0   93516.0
# 26   30392.0  -26079.0  -97069.0 -116949.0  100166.0   10282.0  102435.0
# 27 -220073.0   30392.0  -26079.0  -97069.0 -116949.0  100166.0   10282.0
# 28   -5133.0 -220073.0   30392.0  -26079.0  -97069.0 -116949.0  100166.0
# 29   12518.0   -5133.0 -220073.0   30392.0  -26079.0  -97069.0 -116949.0
# 30  175924.0   12518.0   -5133.0 -220073.0   30392.0  -26079.0  -97069.0
# 31  111069.0  175924.0   12518.0   -5133.0 -220073.0   30392.0  -26079.0
# 32   86780.0  111069.0  175924.0   12518.0   -5133.0 -220073.0   30392.0
# 33   33934.0   86780.0  111069.0  175924.0   12518.0   -5133.0 -220073.0
# 34  116054.0   33934.0   86780.0  111069.0  175924.0   12518.0   -5133.0
# 35 -157224.0  116054.0   33934.0   86780.0  111069.0  175924.0   12518.0
# 36  -84663.0 -157224.0  116054.0   33934.0   86780.0  111069.0  175924.0
# 37  -33194.0  -84663.0 -157224.0  116054.0   33934.0   86780.0  111069.0
# 38   27811.0  -33194.0  -84663.0 -157224.0  116054.0   33934.0   86780.0
# 39 -228037.0   27811.0  -33194.0  -84663.0 -157224.0  116054.0   33934.0
# 40  -46105.0 -228037.0   27811.0  -33194.0  -84663.0 -157224.0  116054.0
# 41    4063.0  -46105.0 -228037.0   27811.0  -33194.0  -84663.0 -157224.0
# 42  201298.0    4063.0  -46105.0 -228037.0   27811.0  -33194.0  -84663.0
# 43  116195.0  201298.0    4063.0  -46105.0 -228037.0   27811.0  -33194.0
# 44   81824.0  116195.0  201298.0    4063.0  -46105.0 -228037.0   27811.0
# 45   43938.0   81824.0  116195.0  201298.0    4063.0  -46105.0 -228037.0
# 46  106769.0   43938.0   81824.0  116195.0  201298.0    4063.0  -46105.0
#
#       lag_12
# 0     4513.0
# 1   157965.0
# 2    64892.0
# 3    80968.0
# 4    32355.0
# 5    60325.0
# 6   -89161.0
# 7   -76854.0
# 8   -33320.0
# 9    36056.0
# 10 -186036.0
# 11   19380.0
# 12    3130.0
# 13  175184.0
# 14   84613.0
# 15   93963.0
# 16   23965.0
# 17   82168.0
# 18 -103414.0
# 19 -100472.0
# 20  -26241.0
# 21   41900.0
# 22 -222735.0
# 23  -25535.0
# 24   -1196.0
# 25  179634.0
# 26   93516.0
# 27  102435.0
# 28   10282.0
# 29  100166.0
# 30 -116949.0
# 31  -97069.0
# 32  -26079.0
# 33   30392.0
# 34 -220073.0
# 35   -5133.0
# 36   12518.0
# 37  175924.0
# 38  111069.0
# 39   86780.0
# 40   33934.0
# 41  116054.0
# 42 -157224.0
# 43  -84663.0
# 44  -33194.0
# 45   27811.0
# 46 -228037.0

# %%
model_df.info() # Supervised Dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        47 non-null     datetime64[ns]
#  1   sales       47 non-null     int64
#  2   sales_diff  47 non-null     float64
#  3   lag_1       47 non-null     float64
#  4   lag_2       47 non-null     float64
#  5   lag_3       47 non-null     float64
#  6   lag_4       47 non-null     float64
#  7   lag_5       47 non-null     float64
#  8   lag_6       47 non-null     float64
#  9   lag_7       47 non-null     float64
#  10  lag_8       47 non-null     float64
#  11  lag_9       47 non-null     float64
#  12  lag_10      47 non-null     float64
#  13  lag_11      47 non-null     float64
#  14  lag_12      47 non-null     float64
# dtypes: datetime64[ns](1), float64(13), int64(1)
# memory usage: 5.6 KB

# %% [markdown]
# two separate data structures:
# 1. Arima structure which includes a DataTime index,
# 2. supervised structure which includes lags as features.

# %% [markdown]
# ## **Functions For Modeling**

# %% [markdown]
# * *Train test split*
# * *Scale the data*
# * *Reverse scaling*
# * *Create a predictions data frame*
# * *Score the models*

# %% [markdown]
#  # Train Test Split
# detach data so that the last 12 months are part of the test set and the rest of the data is used to train our model.

# %%
def train_test_split(data):
    data = data.drop(['sales','date'], axis=1)
    train , test = data[:-12].values, data[-12:].values
    
    return train, test

train, test = train_test_split(model_df)
print(f"Shape of  Train: {train.shape}\nShape of  Test: {test.shape}")
# Out:
# Shape of  Train: (35, 13)
# Shape of  Test: (12, 13)

# %% [markdown]
#  # Scaling the data
# a min-max scaler to scale the data so that all of our variables fall within the range of -1 to 1.

# %%
def scale_data(train_set,test_set):
    """Scales data using MinMaxScaler and separates data into X_train, y_train,
    X_test, and y_test."""
    
    # Apply Min Max Scaler:
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)
    
    # Reshape training set:
    train_set = train_set.reshape(train_set.shape[0],
                                  train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)
    
    # Reshape test set:
    test_set = test_set.reshape(test_set.shape[0], 
                                test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)
    
    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1].ravel() # returns the array, flattened!
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1].ravel()
    
    return X_train, y_train, X_test, y_test, scaler


X_train, y_train, X_test, y_test, scaler_object = scale_data(train, test)
print(f"Shape of X Train: {X_train.shape}\nShape of y Train: {y_train.shape}\nShape of X Test: {X_test.shape}\nShape of y Test: {y_test.shape}")
# Out:
# Shape of X Train: (35, 12)
# Shape of y Train: (35,)
# Shape of X Test: (12, 12)
# Shape of y Test: (12,)

# %% [markdown]
# # Reverse Scaling
# After running our models, we will use this helper function to reverse the scaling of step 2

# %%
def re_scaling(y_pred, x_test, scaler_obj, lstm=False):
    y_pred = y_pred.reshape(y_pred.shape[0],
                            1,
                            1)

    if not lstm:
        x_test = x_test.reshape(x_test.shape[0],
                                1, 
                                x_test.shape[1])

    # Rebuild test set for inverse transform:
    pred_test_set = []
    for index in range(0, len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index], 
                                             x_test[index]],
                                             axis=1) )

    # Reshape pred_test_set:
    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0],
                                          pred_test_set.shape[2])

    # Inverse transform:
    pred_test_set_inverted = scaler_obj.inverse_transform(pred_test_set)

    return pred_test_set_inverted

# %% [markdown]
#  # Predictions_Dataframe
#  Generate a dataframe that includes the actual sales captured in our test set and the predicted results from our model so that we can quantify our success.

# %%
def prediction_df(unscale_predictions, origin_df):
    result_list = []
    sales_dates = list(origin_df[-13:].date)
    act_sales = list(origin_df[-13:].sales)

    for index in range(0, len(unscale_predictions)):
        result_dict = {}
        result_dict['pred_value'] = int(unscale_predictions[index][0] + act_sales[index])
        result_dict['date'] = sales_dates[index + 1]
        result_list.append(result_dict)

    df_result = pd.DataFrame(result_list)

    return df_result

# %% [markdown]
# ![](https://4.bp.blogspot.com/-wG7IbjTfE6k/XGUvqm7TCVI/AAAAAAAAAZU/vpH1kuKTIooKTcVlnm1EVRCXLVZM9cPNgCLcBGAs/s1600/formula-MAE-MSE-RMSE-RSquared.JPG)

# %%
model_scores = {}

def get_scores(unscale_df, origin_df, model_name):
    rmse = np.sqrt(mean_squared_error(origin_df.sales[-12:], 
                                      unscale_df.pred_value[-12:]))
    
    mae = mean_absolute_error(origin_df.sales[-12:], 
                              unscale_df.pred_value[-12:])
    
    r2 = r2_score(origin_df.sales[-12:], 
                  unscale_df.pred_value[-12:])
    
    model_scores[model_name] = [rmse, mae, r2]

    print(f"RMSE: {rmse}\nMAE: {mae}\nR2 Score: {r2}")

# %% [markdown]
# # Graph of Results

# %%
# def plot_results(results, origin_df, model_name):
# # results: a dataframe with unscaled predictions

#     fig, ax = plt.subplots(figsize=(15,5))
#     sns.lineplot(origin_df.date, origin_df.sales, data=origin_df, ax=ax, 
#                  label='Original', color='blue')
#     sns.lineplot(results.date, results.pred_value, data=results, ax=ax, 
#                  label='Predicted', color='red')
    
    
#     ax.set(xlabel = "Date",
#            ylabel = "Sales",
#            title = f"{model_name} Sales Forecasting Prediction")
    
#     ax.legend(loc='best')
    
#     filepath = Path('./model_output/{model_name}_forecasting.svg')  
#     filepath.parent.mkdir(parents=True, exist_ok=True) 
#     plt.savefig(f'./model_output/{model_name}_forecasting.svg')

def plot_results(results, origin_df, model_name):
    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(x='date', y='sales', data=origin_df, ax=ax, 
                 label='Original', color='blue')
    sns.lineplot(x='date', y='pred_value', data=results, ax=ax, 
                 label='Predicted', color='red')
    
    ax.set(xlabel = "Date",
           ylabel = "Sales",
           title = f"{model_name} Sales Forecasting Prediction")
    
    ax.legend(loc='best')
    
    filepath = Path(f'./model_output/{model_name}_forecasting.svg')  
    filepath.parent.mkdir(parents=True, exist_ok=True) 
    plt.savefig(f'./model_output/{model_name}_forecasting.svg')

# %%
def regressive_model(train_data, test_data, model, model_name):
    # Split into X & y and scale data:
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data,
                                                                 test_data)
    # Run sklearn models:
    mod = model
    mod.fit(X_train, y_train)
    predictions = mod.predict(X_test) # y_pred=predictions

    # Undo scaling to compare predictions against original data:
    origin_df = m_df
    unscaled = re_scaling(predictions, X_test, scaler_object) # unscaled_predictions
    unscaled_df = prediction_df(unscaled, origin_df)

    # Print scores and plot results:
    get_scores(unscaled_df, origin_df, model_name)
    plot_results(unscaled_df, origin_df, model_name)

# %% [markdown]
# * Linear Regression
# * Random Forest Regressor
# * XGBoost
# * LSTM

# %% [markdown]
# # [Linear Regression](http://)

# %%
regressive_model(train, test, LinearRegression(), 'LinearRegression')
# Out:
# RMSE: 16221.040790693221
# MAE: 12433.0
# R2 Score: 0.9907155879704752

# %% [markdown]
#  # [ Random Forest Regressor ](https://scikit-learn.org/0.24/modules/generated/sklearn.ensemble.RandomForestRegressor.html?highlight=random%20forest%20reg#sklearn.ensemble.RandomForestRegressor)

# %%
regressive_model(train, test, RandomForestRegressor(n_estimators=100, max_depth=20), 
          'RandomForest')
# Out:
# RMSE: 17916.02511952172
# MAE: 14875.083333333334
# R2 Score: 0.988673902441114

# %% [markdown]
# # [  XGBoost](https://xgboost.readthedocs.io/en/stable/parameter.html)

# %%
regressive_model(train, test, XGBRegressor(n_estimators=100,max_depth=3, 
                                           learning_rate=0.2,objective='reg:squarederror'), 'XGBoost')
# Out:
# RMSE: 22730.366245766185
# MAE: 18379.166666666668
# R2 Score: 0.9817690273475503

# %% [markdown]
# # LSTM

# %%
def lstm_model(train_data, test_data):
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

    # # Build LSTM:
    # model = Sequential()
    # model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), 
    #                stateful=True))
    # model.add(Dense(1))
    # model.add(Dense(1))
    # model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    # model.fit(X_train, y_train, epochs=50, batch_size=1, verbose=1, 
    #           shuffle=False)
    # predictions = model.predict(X_test,batch_size=1)

    model = Sequential()
    model.add(LSTM(4, input_shape=(X_train.shape[1], X_train.shape[2]), stateful=False))
    model.add(Dense(1))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
    model.fit(X_train, y_train, epochs=50, batch_size=1, verbose=1, 
              shuffle=False)
    predictions = model.predict(X_test, batch_size=1)
    
    # Undo scaling to compare predictions against original data:
    origin_df = m_df
    unscaled = re_scaling(predictions, X_test, scaler_object, lstm=True)
    unscaled_df = prediction_df(unscaled, origin_df)
    
    get_scores(unscaled_df, origin_df, 'LSTM')
    plot_results(unscaled_df, origin_df, 'LSTM')

# %%
lstm_model(train,test)
# Out:
# d:\PYTHON_WORKSPACE\Sales_DA\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.0000e+00 - loss: 0.2736
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.2528
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.2373
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.2223
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.2074
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.1926
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.1777
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.1628
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.1479
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.1332
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.1190
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.1056
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0930
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0816
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0713
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0623
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0544
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0476
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0419
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0370
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0328
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0293
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0263
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0237
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0215
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0276 - loss: 0.0195
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0178
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0276 - loss: 0.0163
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0276 - loss: 0.0150
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0138
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0127
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0276 - loss: 0.0117
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0276 - loss: 0.0108
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0101
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0093
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0087
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0276 - loss: 0.0081
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0076
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0071
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0067
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0276 - loss: 0.0063
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0059
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0056
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0053
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0276 - loss: 0.0050
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0048
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0276 - loss: 0.0046
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0276 - loss: 0.0044
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0276 - loss: 0.0042
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0276 - loss: 0.0040
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# RMSE: 16554.583615019335
# MAE: 12961.166666666666
# R2 Score: 0.9903298436425307

# %%
pickle.dump(model_scores, open( "model_scores.p", "wb" ))

# %% [markdown]
# # ARIMA Modeling

# %%
datatime_df.index = pd.to_datetime(datatime_df.index)

# %% [markdown]
# making dynamic predictions for the last 12 months of the data. For standard, non-dynamic predictions, the following month’s prediction is made using the actual sales from the prior months. In contrast, for dynamic predictions, the following month’s prediction is made using the predicted sales from the prior months.

# %%
def sarimax_model(data):
    sar = sm.tsa.statespace.SARIMAX(data.sales_diff, order=(12, 0, 0),
                                    seasonal_order=(0, 1, 0, 12),
                                    trend='c').fit()
    start, end, dynamic = 40, 100, 7
    data['pred_value'] = sar.predict(start=start, end=end, dynamic=dynamic)
    pred_df = data.pred_value[start+dynamic:end]
    
    data[["sales_diff","pred_value"]].plot(color=['blue', 'Red'])
    plt.legend(loc='upper left')
    
    rmse = np.sqrt(mean_squared_error(data.sales_diff[-12:], data.pred_value[-12:]))
    mae = mean_absolute_error(data.sales_diff[-12:], data.pred_value[-12:])
    r2 = r2_score(data.sales_diff[-12:], data.pred_value[-12:])
    model_scores['ARIMA'] = [rmse, mae, r2]
    
    print(f"RMSE: {rmse}\nMAE: {mae}\nR2 Score: {r2}")
    
    return sar, data, pred_df

# %%
sar, datatime_df, predictions = sarimax_model(datatime_df)
# Out:
# d:\PYTHON_WORKSPACE\Sales_DA\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# d:\PYTHON_WORKSPACE\Sales_DA\.venv\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# RMSE: 14959.893464683544
# MAE: 11265.335750585647
# R2 Score: 0.9835642876268827

# %% [markdown]
# [statsmodels](https://www.statsmodels.org/dev/generated/statsmodels.tsa.arima.model.ARIMAResults.plot_diagnostics.html)

# %%
sar.plot_diagnostics(figsize=(12, 8));

# %%
pickle.dump(model_scores, open( "ARIMAmodel_scores.p", "wb" ))

# %% [markdown]
# ## **Comparing Models**

# %%
def create_results_df():
    results_dict = pickle.load(open("model_scores.p", "rb"))
    
    results_dict.update(pickle.load(open("ARIMAmodel_scores.p", "rb")))
    
    results_df = pd.DataFrame.from_dict(results_dict, orient='index', 
                                        columns=['RMSE', 'MAE','R2'])
    
    results_df = results_df.sort_values(by='RMSE', ascending=False).reset_index()
    
    results_df.to_csv('./results.csv')
    
#     fig, ax = plt.subplots(figsize=(12, 5))
#     sns.lineplot(np.arange(len(results_df)), 'RMSE', data=results_df, ax=ax, 
#                  label='RMSE', color='darkblue')
#     sns.lineplot(np.arange(len(results_df)), 'MAE', data=results_df, ax=ax, 
#                  label='MAE', color='Cyan')
    
#     plt.xticks(np.arange(len(results_df)),rotation=45)
#     ax.set_xticklabels(results_df['index'])
#     ax.set(xlabel = "Model",
#            ylabel = "Scores",
#            title = "Model Error Comparison")
#     sns.despine()
    
#     plt.savefig(f'./model_output/compare_models.png')
    
#     return results_df
    
    fig, ax = plt.subplots(figsize=(12, 5))
    sns.lineplot(x=np.arange(len(results_df)), y='RMSE', data=results_df, ax=ax, 
                 label='RMSE', color='darkblue')
    sns.lineplot(x=np.arange(len(results_df)), y='MAE', data=results_df, ax=ax, 
                 label='MAE', color='Cyan')
    
    plt.xticks(np.arange(len(results_df)), rotation=45)
    ax.set_xticklabels(results_df['index'])
    ax.set(xlabel="Model",
           ylabel="Scores",
           title="Model Error Comparison")
    sns.despine()
    
    plt.savefig(f'./model_output/compare_models.png')
    
    return results_df

# %%
results = create_results_df()
results
# Out:
#               index          RMSE           MAE        R2
# 0           XGBoost  22730.366246  18379.166667  0.981769
# 1      RandomForest  17916.025120  14875.083333  0.988674
# 2              LSTM  16554.583615  12961.166667  0.990330
# 3  LinearRegression  16221.040791  12433.000000  0.990716
# 4             ARIMA  14959.893465  11265.335751  0.983564

# %%
avarage_12months()
# Out:
# Last 12 months average monthly sales: $894478.3333333334

# %%
average = 894478.3333333334
XGBoost = results.MAE.values[4]
percentage_off = round(XGBoost/average*100,2)
print(f"With XGBoost, prediction is within {percentage_off}% of the actual.")
# Out:
# With XGBoost, prediction is within 1.26% of the actual.
